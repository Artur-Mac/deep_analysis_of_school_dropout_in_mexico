# %%
import pandas as pd

# %%
path = "../data/raw/df03_Dataset_ENAPE.csv"
df = pd.read_csv(path)
df
# Out:
#        FOLIO  SEXO  EDAD  edu_inicial  inscrito  nivel_edu  terminado  \
# 0          2     1    13          0.0       1.0        3.0        1.0
# 1          2     2    19          0.0       1.0        9.0        1.0
# 2          7     2     8          0.0       1.0        3.0        1.0
# 3          7     1    26          0.0       2.0        0.0        0.0
# 4          9     1    27          0.0       1.0        9.0        1.0
# ...      ...   ...   ...          ...       ...        ...        ...
# 32338  22717     2    23          0.0       1.0        9.0        1.0
# 32339  22717     1    25          0.0       1.0        9.0        1.0
# 32340  22717     2    22          0.0       1.0        9.0        1.0
# 32341  22718     1    11          0.0       1.0        3.0        1.0
# 32342  22718     1    24          0.0       2.0        0.0        0.0
#
#        nt_causa  asesorias  extraord  ...  tv_plana  tablet  smartphone  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32343 entries, 0 to 32342
# Data columns (total 67 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FOLIO            32343 non-null  int64
#  1   SEXO             32343 non-null  int64
#  2   EDAD             32343 non-null  int64
#  3   edu_inicial      32343 non-null  float64
#  4   inscrito         32343 non-null  float64
#  5   nivel_edu        32343 non-null  float64
#  6   terminado        32343 non-null  float64
#  7   nt_causa         32343 non-null  float64
#  8   asesorias        32343 non-null  float64
#  9   extraord         32343 non-null  float64
#  10  recursado        32343 non-null  float64
#  11  ev_tareas        32343 non-null  float64
#  12  ev_exam          32343 non-null  float64
#  13  ev_digital       32343 non-null  float64
#  14  ev_partcp        32343 non-null  float64
#  15  ev_libreta       32343 non-null  float64
# ...

# %%
df = df.drop(columns=["FOLIO", "x<30", "q_personas", "FACTOR_y"])

# %%
analValues = df[
    (df["nivel_edu"] == 4) & (df["EDAD"] >= 3) & (df["EDAD"] <= 17)
].groupby("t_mama")["t_mama"].count()
total = analValues.sum()
analValues = analValues.div(total) * 100

print(total)
analValues
# Out:
# Total de estudantes na amostra: 3452
# População total ponderada (denominador): 5542782
# População ponderada com ajuda da mãe (numerador): 2228495
# Porcentagem ponderada de ajuda da mãe: 40.2%
